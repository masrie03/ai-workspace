# %%
# Numerical computations
import numpy as np

# Data handling
import pandas as pd

# Visualization
import matplotlib.pyplot as plt

# Machine learning model
from sklearn.linear_model import LinearRegression

# Model evaluation
from sklearn.metrics import mean_squared_error

# %%
# Create input data (X)
# Example: years of experience
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)

# Create output data (y)
# Example: salary (in thousands)
y = np.array([30, 35, 40, 45, 50])

# Why reshape?
# scikit-learn expects 2D arrays for features
# Shape becomes (samples, features)

# %%
plt.scatter(X, y)
plt.xlabel("Years of Experience")
plt.ylabel("Salary (k)")
plt.title("Training Data")
plt.show()

# %%
# Create the model
model = LinearRegression()

# Train the model on the data
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Weight (slope)
w = model.coef_[0]

# Bias (intercept)
b = model.intercept_

print("Weight (w):", w)
print("Bias (b):", b)
# Out:
# Weight (w): 4.999999999999999
# Bias (b): 25.000000000000004

# %%
# Predict using the trained model
y_pred = model.predict(X)

print("Predicted values:", y_pred)
# Out:
# Predicted values: [30. 35. 40. 45. 50.]

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 2.524354896707238e-30

# %%
plt.scatter(X, y, label="Actual Data")
plt.plot(X, y_pred, color="red", label="Regression Line")
plt.xlabel("Years of Experience")
plt.ylabel("Salary (k)")
plt.legend()
plt.show()
